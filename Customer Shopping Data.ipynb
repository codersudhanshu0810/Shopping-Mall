# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the Data

# %%
df = pd.read_csv('customer_shopping_data.csv')
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
df.columns = np.char.title(list(df.columns))
df
# Out:
#       Invoice_No Customer_Id  Gender  Age         Category  Quantity    Price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %% [markdown]
# # isnull()

# %%
df.isnull().sum()
# Out:
# Invoice_No        0
# Customer_Id       0
# Gender            0
# Age               0
# Category          0
# Quantity          0
# Price             0
# Payment_Method    0
# Invoice_Date      0
# Shopping_Mall     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Invoice_No      99457 non-null  object
#  1   Customer_Id     99457 non-null  object
#  2   Gender          99457 non-null  object
#  3   Age             99457 non-null  int64
#  4   Category        99457 non-null  object
#  5   Quantity        99457 non-null  int64
#  6   Price           99457 non-null  float64
#  7   Payment_Method  99457 non-null  object
#  8   Invoice_Date    99457 non-null  object
#  9   Shopping_Mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %%
df['Invoice_No'] = df['Invoice_No'].str.replace('I', '')
df['Customer_Id'] = df['Customer_Id'].str.replace('C', '')
df
# Out:
#       Invoice_No Customer_Id  Gender  Age         Category  Quantity    Price  \
# 0         138884      241288  Female   28         Clothing         5  1500.40
# 1         317333      111565    Male   21            Shoes         3  1800.51
# 2         127801      266599    Male   20         Clothing         1   300.08
# 3         173702      988172  Female   66            Shoes         5  3000.85
# 4         337046      189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452     219422      441542  Female   45         Souvenir         5    58.65
# 99453     325143      569580    Male   27  Food & Beverage         2    10.46
# 99454     824010      103292    Male   63  Food & Beverage         2    10.46
# 99455     702964      800631    Male   56       Technology         4  4200.00
# 99456     232867      273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Invoice_No      99457 non-null  object
#  1   Customer_Id     99457 non-null  object
#  2   Gender          99457 non-null  object
#  3   Age             99457 non-null  int64
#  4   Category        99457 non-null  object
#  5   Quantity        99457 non-null  int64
#  6   Price           99457 non-null  float64
#  7   Payment_Method  99457 non-null  object
#  8   Invoice_Date    99457 non-null  object
#  9   Shopping_Mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %% [markdown]
# # Type Conversion

# %%
df['Invoice_No'] = df['Invoice_No'].astype(int)
df['Customer_Id'] = df['Customer_Id'].astype(int)
df['Invoice_Date'] = df['Invoice_Date'].str.replace('/', '-')
df
# Out:
#        Invoice_No  Customer_Id  Gender  Age         Category  Quantity  \
# 0          138884       241288  Female   28         Clothing         5
# 1          317333       111565    Male   21            Shoes         3
# 2          127801       266599    Male   20         Clothing         1
# 3          173702       988172  Female   66            Shoes         5
# 4          337046       189076  Female   53            Books         4
# ...           ...          ...     ...  ...              ...       ...
# 99452      219422       441542  Female   45         Souvenir         5
# 99453      325143       569580    Male   27  Food & Beverage         2
# 99454      824010       103292    Male   63  Food & Beverage         2
# 99455      702964       800631    Male   56       Technology         4
# 99456      232867       273973  Female   36         Souvenir         3
#
#          Price Payment_Method Invoice_Date     Shopping_Mall
# ...

# %%
df['Invoice_Date'] = pd.to_datetime(df['Invoice_Date'], format='%d-%m-%Y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Invoice_No      99457 non-null  int32
#  1   Customer_Id     99457 non-null  int32
#  2   Gender          99457 non-null  object
#  3   Age             99457 non-null  int64
#  4   Category        99457 non-null  object
#  5   Quantity        99457 non-null  int64
#  6   Price           99457 non-null  float64
#  7   Payment_Method  99457 non-null  object
#  8   Invoice_Date    99457 non-null  datetime64[ns]
#  9   Shopping_Mall   99457 non-null  object
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(2), object(4)
# memory usage: 6.8+ MB

# %%
df['Amount'] = df['Quantity'] * df['Price']
df
# Out:
#        Invoice_No  Customer_Id  Gender  Age         Category  Quantity  \
# 0          138884       241288  Female   28         Clothing         5
# 1          317333       111565    Male   21            Shoes         3
# 2          127801       266599    Male   20         Clothing         1
# 3          173702       988172  Female   66            Shoes         5
# 4          337046       189076  Female   53            Books         4
# ...           ...          ...     ...  ...              ...       ...
# 99452      219422       441542  Female   45         Souvenir         5
# 99453      325143       569580    Male   27  Food & Beverage         2
# 99454      824010       103292    Male   63  Food & Beverage         2
# 99455      702964       800631    Male   56       Technology         4
# 99456      232867       273973  Female   36         Souvenir         3
#
#          Price Payment_Method Invoice_Date     Shopping_Mall    Amount
# ...

# %% [markdown]
# # Value Counts

# %%
gdf = df['Gender'].value_counts()
gdf = gdf.reset_index()
gdf
# Out:
#    Gender  count
# 0  Female  59482
# 1    Male  39975

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (10, 5))
plt.bar(gdf['Gender'], gdf['count'])
plt.title('Shopping according to Gender')
plt.xlabel('Gender')
plt.ylabel('Gender Count')
plt.savefig('Shopping according to Gender.png', format='png')

# %% [markdown]
# # Category Count

# %%
cdf = df['Category'].value_counts()
cdf = cdf.reset_index()
cdf
# Out:
#           Category  count
# 0         Clothing  34487
# 1        Cosmetics  15097
# 2  Food & Beverage  14776
# 3             Toys  10087
# 4            Shoes  10034
# 5         Souvenir   4999
# 6       Technology   4996
# 7            Books   4981

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (15, 5))
plt.bar(cdf['Category'], cdf['count'])
plt.title('Shopping according to Category')
plt.xlabel('Category')
plt.ylabel('Category Count')
plt.savefig('Shopping according to Category.png', format='png')

# %% [markdown]
# # Payment Method Count

# %%
pdf = df['Payment_Method'].value_counts()
pdf = pdf.reset_index()
pdf
# Out:
#   Payment_Method  count
# 0           Cash  44447
# 1    Credit Card  34931
# 2     Debit Card  20079

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (15, 5))
plt.bar(pdf['Payment_Method'], pdf['count'])
plt.title('Shopping according to Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Method Count')
plt.savefig('Shopping according to Payment Method.png', format='png')

# %%
df
# Out:
#        Invoice_No  Customer_Id  Gender  Age         Category  Quantity  \
# 0          138884       241288  Female   28         Clothing         5
# 1          317333       111565    Male   21            Shoes         3
# 2          127801       266599    Male   20         Clothing         1
# 3          173702       988172  Female   66            Shoes         5
# 4          337046       189076  Female   53            Books         4
# ...           ...          ...     ...  ...              ...       ...
# 99452      219422       441542  Female   45         Souvenir         5
# 99453      325143       569580    Male   27  Food & Beverage         2
# 99454      824010       103292    Male   63  Food & Beverage         2
# 99455      702964       800631    Male   56       Technology         4
# 99456      232867       273973  Female   36         Souvenir         3
#
#          Price Payment_Method Invoice_Date     Shopping_Mall    Amount
# ...

# %% [markdown]
# # Shopping Malls Counts

# %%
sdf = df['Shopping_Mall'].value_counts()
sdf = sdf.reset_index()
sdf
# Out:
#        Shopping_Mall  count
# 0   Mall of Istanbul  19943
# 1             Kanyon  19823
# 2          Metrocity  15011
# 3       Metropol AVM  10161
# 4       Istinye Park   9781
# 5       Zorlu Center   5075
# 6        Cevahir AVM   4991
# 7     Forum Istanbul   4947
# 8     Viaport Outlet   4914
# 9  Emaar Square Mall   4811

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (18, 5))
plt.bar(sdf['Shopping_Mall'], sdf['count'])
plt.title('Shopping according to Shopping Mall')
plt.xlabel('Shopping Mall')
plt.ylabel('Shopping Malls Count')
plt.savefig('Shopping according to Shopping Mall.png', format='png')

# %%
df
# Out:
#        Invoice_No  Customer_Id  Gender  Age         Category  Quantity  \
# 0          138884       241288  Female   28         Clothing         5
# 1          317333       111565    Male   21            Shoes         3
# 2          127801       266599    Male   20         Clothing         1
# 3          173702       988172  Female   66            Shoes         5
# 4          337046       189076  Female   53            Books         4
# ...           ...          ...     ...  ...              ...       ...
# 99452      219422       441542  Female   45         Souvenir         5
# 99453      325143       569580    Male   27  Food & Beverage         2
# 99454      824010       103292    Male   63  Food & Beverage         2
# 99455      702964       800631    Male   56       Technology         4
# 99456      232867       273973  Female   36         Souvenir         3
#
#          Price Payment_Method Invoice_Date     Shopping_Mall    Amount
# ...

# %% [markdown]
# # Groupby

# %%
ndf = df.groupby('Gender').agg(Earning_by_Gender = ('Amount', 'sum'))
ndf = ndf.reset_index().sort_values(by='Earning_by_Gender', ascending=False)
ndf
# Out:
#    Gender  Earning_by_Gender
# 0  Female       1.502071e+08
# 1    Male       1.012987e+08

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             2 non-null      object
#  1   Earning_by_Gender  2 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 160.0+ bytes

# %%
plt.figure(figsize = (10, 5))
plt.bar(ndf['Gender'], ndf['Earning_by_Gender'])
plt.title('Earning according to Gender')
plt.xlabel('Gender')
plt.ylabel('Earning')
plt.savefig('Earning according to Gender.png', format='png')

# %% [markdown]
# # Groupby

# %%
kdf = df.groupby('Category').agg(Earning_by_Category = ('Amount', 'sum'))
kdf = kdf.reset_index().sort_values(by='Earning_by_Category', ascending=False)
kdf
# Out:
#           Category  Earning_by_Category
# 1         Clothing         1.139968e+08
# 4            Shoes         6.655345e+07
# 6       Technology         5.786235e+07
# 2        Cosmetics         6.792863e+06
# 7             Toys         3.980426e+06
# 3  Food & Beverage         8.495351e+05
# 0            Books         8.345529e+05
# 5         Souvenir         6.358247e+05

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (18, 5))
plt.bar(kdf['Category'], kdf['Earning_by_Category'])
plt.title('Earning according to Category')
plt.xlabel('Category')
plt.ylabel('Earning')
plt.savefig('Earning according to Category.png', format='png')

# %%
df
# Out:
#        Invoice_No  Customer_Id  Gender  Age         Category  Quantity  \
# 0          138884       241288  Female   28         Clothing         5
# 1          317333       111565    Male   21            Shoes         3
# 2          127801       266599    Male   20         Clothing         1
# 3          173702       988172  Female   66            Shoes         5
# 4          337046       189076  Female   53            Books         4
# ...           ...          ...     ...  ...              ...       ...
# 99452      219422       441542  Female   45         Souvenir         5
# 99453      325143       569580    Male   27  Food & Beverage         2
# 99454      824010       103292    Male   63  Food & Beverage         2
# 99455      702964       800631    Male   56       Technology         4
# 99456      232867       273973  Female   36         Souvenir         3
#
#          Price Payment_Method Invoice_Date     Shopping_Mall    Amount
# ...

# %% [markdown]
# # Groupby

# %%
idf = df.groupby('Payment_Method').agg(PaymentMethod = ('Amount', 'sum'))
idf = idf.reset_index().sort_values(by = 'PaymentMethod', ascending=False)
idf
# Out:
#   Payment_Method  PaymentMethod
# 0           Cash   1.128322e+08
# 1    Credit Card   8.807712e+07
# 2     Debit Card   5.059643e+07

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (18, 5))
plt.plot(idf['Payment_Method'], idf['PaymentMethod'])
plt.title('Earning according to Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Amount')
plt.savefig('Earning by Payment Method.png', format='png')

# %% [markdown]
# # Groupby

# %%
jdf = df.groupby('Shopping_Mall').agg(Shopping_Mart = ('Amount', 'sum'))
jdf = jdf.reset_index().sort_values(by = 'Shopping_Mart', ascending=False)
jdf
# Out:
#        Shopping_Mall  Shopping_Mart
# 5   Mall of Istanbul    50872481.68
# 4             Kanyon    50554231.10
# 6          Metrocity    37302787.33
# 7       Metropol AVM    25379913.19
# 3       Istinye Park    24618827.68
# 9       Zorlu Center    12901053.82
# 0        Cevahir AVM    12645138.20
# 8     Viaport Outlet    12521339.72
# 1  Emaar Square Mall    12406100.29
# 2     Forum Istanbul    12303921.24

# %%
plt.figure(figsize = (18, 5))
plt.bar(jdf['Shopping_Mall'], jdf['Shopping_Mart'])
plt.title('Earning from Shopping Mall')
plt.xlabel('Shopping Mall')
plt.ylabel('Amount')
plt.savefig('Earning by Shopping Mall.png', format='png')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Invoice_No      99457 non-null  int32
#  1   Customer_Id     99457 non-null  int32
#  2   Gender          99457 non-null  object
#  3   Age             99457 non-null  int64
#  4   Category        99457 non-null  object
#  5   Quantity        99457 non-null  int64
#  6   Price           99457 non-null  float64
#  7   Payment_Method  99457 non-null  object
#  8   Invoice_Date    99457 non-null  datetime64[ns]
#  9   Shopping_Mall   99457 non-null  object
#  10  Amount          99457 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(2), object(4)
# memory usage: 7.6+ MB

# %%
df['Month Name'] = df['Invoice_Date'].dt.month_name()
df
# Out:
#        Invoice_No  Customer_Id  Gender  Age         Category  Quantity  \
# 0          138884       241288  Female   28         Clothing         5
# 1          317333       111565    Male   21            Shoes         3
# 2          127801       266599    Male   20         Clothing         1
# 3          173702       988172  Female   66            Shoes         5
# 4          337046       189076  Female   53            Books         4
# ...           ...          ...     ...  ...              ...       ...
# 99452      219422       441542  Female   45         Souvenir         5
# 99453      325143       569580    Male   27  Food & Beverage         2
# 99454      824010       103292    Male   63  Food & Beverage         2
# 99455      702964       800631    Male   56       Technology         4
# 99456      232867       273973  Female   36         Souvenir         3
#
#          Price Payment_Method Invoice_Date     Shopping_Mall    Amount  \
# ...

# %%
rdf = df.groupby('Month Name').agg(HighestSales = ('Amount', 'sum'))
rdf = rdf.reset_index().sort_values(by='HighestSales', ascending=False)
rdf
# Out:
#    Month Name  HighestSales
# 4     January   28891525.59
# 3    February   26625090.10
# 7       March   21956191.33
# 10    October   20545090.43
# 5        July   20378722.63
# 8         May   19719331.10
# 2    December   19455085.64
# 1      August   19282361.29
# 6        June   18933775.30
# 11  September   18795794.91
# 0       April   18715685.98
# 9    November   18207139.95

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (18, 5))
plt.bar(rdf['Month Name'], rdf['HighestSales'])
plt.title('Earning in Month')
plt.xlabel('Month Name')
plt.ylabel('Amount')
plt.savefig('Earning in Shopping Month.png', format='png')
